# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import validation_curve
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import seaborn as sns
from keras.datasets import mnist
from sklearn.preprocessing import scale
import import_ipynb
import sce_pipeline
# Out:
# importing Jupyter notebook from sce_pipeline.ipynb

# %%
(balanced_X_train, balanced_Y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train_imbalanced = np.load('./datasets/x_train_imbalanced.npy')
y_train_imbalanced = np.load('./datasets/y_train_imbalanced.npy')
y_train_imbalanced_sym = np.load('./datasets/y_train_imbalanced_sym.npy')

# %%
print('Original Shape')
print('X_train: ' + str(x_train_imbalanced.shape))
print('Y_train: ' + str(y_train_imbalanced_sym.shape))
print('X_test:  '  + str(x_test.shape))
print('Y_test:  '  + str(y_test.shape))
# Out:
# Original Shape
# X_train: (45209, 28, 28)
# Y_train: (45209,)
# X_test:  (10000, 28, 28)
# Y_test:  (10000,)

# %%
x_train_imbalanced, y_train_imbalanced_sym, x_test, y_test = sce_pipeline.preprocess_sce(x_train_imbalanced, y_train_imbalanced_sym, x_test, y_test)

# %%
sce_pipeline.sce_train(x_train_imbalanced, y_train_imbalanced_sym, x_test, y_test, batch_size=128, epochs=120, alpha = 0.01, beta = 1.0)
# Out:
# Loading Data
# n_images 45209 num_classes 10 image_shape: (28, 28, 1)
# Loading and compiling model
# Training model
# Epoch 1/120
# 354/353 [==============================] - 24s 67ms/step - loss: 0.4906 - categorical_accuracy: 0.9518 - precision: 0.9594 - recall: 0.9496 - auc: 0.9900 - val_loss: 0.2594 - val_categorical_accuracy: 0.9728 - val_precision: 0.9733 - val_recall: 0.9726 - val_auc: 0.9939
# Epoch 2/120
# 354/353 [==============================] - 24s 69ms/step - loss: 0.2241 - categorical_accuracy: 0.9772 - precision: 0.9775 - recall: 0.9769 - auc: 0.9931 - val_loss: 0.1334 - val_categorical_accuracy: 0.9861 - val_precision: 0.9867 - val_recall: 0.9860 - val_auc: 0.9975
# Epoch 3/120
# 354/353 [==============================] - 24s 68ms/step - loss: 0.1937 - categorical_accuracy: 0.9799 - precision: 0.9801 - recall: 0.9798 - auc: 0.9936 - val_loss: 0.1513 - val_categorical_accuracy: 0.9842 - val_precision: 0.9847 - val_recall: 0.9841 - val_auc: 0.9966
# Epoch 4/120
# ...
