# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import validation_curve
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import seaborn as sns
from keras.datasets import mnist
from sklearn.preprocessing import scale
import import_ipynb
import sce_pipeline
# Out:
# importing Jupyter notebook from sce_pipeline.ipynb

# %%
(x_train_balanced, y_train_balanced), (x_test, y_test) = mnist.load_data()

# %%
x_train_imbalanced = np.load('../datasets/x_train_imbalanced.npy')
y_train_imbalanced = np.load('../datasets/y_train_imbalanced.npy')

# %%
x_train_imbalanced, y_train_imbalanced, x_test, y_test = sce_pipeline.preprocess_sce(x_train_imbalanced, y_train_imbalanced, x_test, y_test)

# %%
sce_pipeline.sce_train(x_train_imbalanced, y_train_imbalanced, x_test, y_test, batch_size=128, epochs=30, alpha = 0.01, beta = 1.0)
# Out:
# Loading Data
# n_images 36344 num_classes 10 image_shape: (28, 28, 1)
# Loading and compiling model
# Training model
# Epoch 1/30
# 284/283 [==============================] - 20s 70ms/step - loss: 0.4925 - categorical_accuracy: 0.9516 - precision: 0.9590 - recall: 0.9487 - auc: 0.9922 - val_loss: 0.2877 - val_categorical_accuracy: 0.9712 - val_precision: 0.9718 - val_recall: 0.9709 - val_auc: 0.9942
# Epoch 2/30
# 284/283 [==============================] - 20s 69ms/step - loss: 0.1935 - categorical_accuracy: 0.9804 - precision: 0.9809 - recall: 0.9802 - auc: 0.9961 - val_loss: 0.1975 - val_categorical_accuracy: 0.9798 - val_precision: 0.9800 - val_recall: 0.9797 - val_auc: 0.9961
# Epoch 3/30
# 284/283 [==============================] - 20s 71ms/step - loss: 0.1503 - categorical_accuracy: 0.9849 - precision: 0.9852 - recall: 0.9847 - auc: 0.9965 - val_loss: 0.4368 - val_categorical_accuracy: 0.9547 - val_precision: 0.9556 - val_recall: 0.9544 - val_auc: 0.9890
# Epoch 4/30
# ...
