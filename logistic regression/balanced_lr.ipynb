# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import validation_curve
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import seaborn as sns
from keras.datasets import mnist
from sklearn.preprocessing import scale
import import_ipynb
import LR_function
# Out:
# importing Jupyter notebook from LR_function.ipynb

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
print('X_train: ' + str(x_train.shape))
print('Y_train: ' + str(y_train.shape))
print('X_test:  '  + str(x_test.shape))
print('Y_test:  '  + str(y_test.shape))

type(x_train)
# Out:
# X_train: (60000, 28, 28)
# Y_train: (60000,)
# X_test:  (10000, 28, 28)
# Y_test:  (10000,)
# numpy.ndarray

# %%
num_row = 2
num_col = 5# plot images
fig, axes = plt.subplots(num_row, num_col, figsize=(1.5*num_col,2*num_row))
for i in range(10):
    ax = axes[i//num_col, i%num_col]
    ax.imshow(x_train[i+3], cmap='gray')
plt.tight_layout()
plt.show()

# %%
 #merging all data into single set
y = np.concatenate((y_train,y_test))
x = np.concatenate((x_train,x_test))

print(x.shape)
print(y.shape)
# Out:
# (70000, 28, 28)
# (70000,)

# %%
#verify clean join of x and y

for i in range(70000):
    clean = True
    if(i<60000):  
        if((x[i] != x_train[i]).all() or y[i] != y_train[i]):
            clean=False
            break
    else:
        if((x[i] != x_test[i-60000]).all() or y[i] != y_test[i-60000]):
            clean=False
            break
print(clean)
# Out:
# True

# %%
plt.plot(figure = (16,10))
g = sns.countplot(x=y, palette = 'icefire')
plt.title('Number of digit classes')
# Out:
# Text(0.5, 1.0, 'Number of digit classes')

# %%
#reshaping
x_train = x_train.reshape(len(x_train),-1)
x_test = x_test.reshape(len(x_test),-1)
x_train = x_train/255.0
x_test = x_test/255.0

x_train = scale(x_train)
x_test = scale(x_test)

# %%
LR_function.apply_LR(x_train,x_test,y_train,y_test)
# Out:
# Training started at : 20:26:32
# [Parallel(n_jobs=5)]: Using backend ThreadingBackend with 5 concurrent workers.
# convergence after 37 epochs took 156 seconds
# Accuracy :  0.9154
#
# Precision :  0.9154
#
# Recall :  0.9154
#
# F1 score  :  0.9154
#
# AUC score  :  0.992768266603275
#
# Training Stopped at : 20:29:08
# Total time taken in mins:  2.6034409046173095
# [Parallel(n_jobs=5)]: Done   1 out of   1 | elapsed:  2.6min finished
