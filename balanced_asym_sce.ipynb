# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import validation_curve
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import seaborn as sns
from keras.datasets import mnist
from sklearn.preprocessing import scale
import import_ipynb
import sce_pipeline
# Out:
# importing Jupyter notebook from sce_pipeline.ipynb

# %%
(x_train_balanced, y_train_balanced), (x_test, y_test) = mnist.load_data()

# %%
y_train_balanced_asym = np.load('../datasets/y_train_balanced_asym.npy')

# %%
x_train_balanced, y_train_balanced_asym, x_test, y_test = sce_pipeline.preprocess_sce(x_train_balanced, y_train_balanced_asym, x_test, y_test)

# %%
sce_pipeline.sce_train(x_train_balanced, y_train_balanced_asym, x_test, y_test, batch_size=128, epochs=20, alpha = 0.01, beta = 1.0)
# Out:
# Loading Data
# n_images 60000 num_classes 10 image_shape: (28, 28, 1)
# Loading and compiling model
# C:\Users\rahul\anaconda3\lib\site-packages\keras\optimizer_v2\gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Training model
# Epoch 1/20
# 468/468 [==============================] - 25s 52ms/step - loss: 2.2868 - categorical_accuracy: 0.7587 - precision: 0.7632 - recall: 0.7564 - auc: 0.8844 - val_loss: 0.5924 - val_categorical_accuracy: 0.9379 - val_precision: 0.9386 - val_recall: 0.9376 - val_auc: 0.9849
# Epoch 2/20
# 468/468 [==============================] - 25s 54ms/step - loss: 2.0006 - categorical_accuracy: 0.7874 - precision: 0.7878 - recall: 0.7872 - auc: 0.8892 - val_loss: 0.3498 - val_categorical_accuracy: 0.9642 - val_precision: 0.9645 - val_recall: 0.9638 - val_auc: 0.9906
# Epoch 3/20
# ...
