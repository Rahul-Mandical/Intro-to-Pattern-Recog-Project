# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import validation_curve
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import seaborn as sns
from keras.datasets import mnist
from sklearn.preprocessing import scale
import import_ipynb
import sce_pipeline

# %%
(balanced_X_train, balanced_Y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train_imbalanced = np.load('./datasets/x_train_imbalanced.npy')
y_train_imbalanced = np.load('./datasets/y_train_imbalanced.npy')

# %%
print('Original Shape')
print('X_train: ' + str(x_train_imbalanced.shape))
print('Y_train: ' + str(y_train_imbalanced.shape))
print('X_test:  '  + str(x_test.shape))
print('Y_test:  '  + str(y_test.shape))
# Out:
# Original Shape
# X_train: (45209, 28, 28)
# Y_train: (45209,)
# X_test:  (10000, 28, 28)
# Y_test:  (10000,)

# %%
x_train_imbalanced, y_train_imbalanced, x_test, y_test = sce_pipeline.preprocess_sce(x_train_imbalanced, y_train_imbalanced, x_test, y_test)

# %%
print('Preprocessed Shape')

print('X_train: ' + str(x_train_imbalanced.shape))
print('Y_train: ' + str(y_train_imbalanced.shape))
print('X_test:  '  + str(x_test.shape))
print('Y_test:  '  + str(y_test.shape))
# Out:
# Preprocessed Shape
# X_train: (45209, 28, 28, 1)
# Y_train: (45209, 10)
# X_test:  (10000, 28, 28, 1)
# Y_test:  (10000, 10)

# %%
sce_pipeline.sce_train(x_train_imbalanced, y_train_imbalanced, x_test, y_test, batch_size=128, epochs=120, alpha = 0.01, beta = 1.0)
# Out:
# Loading Data
# n_images 45209 num_classes 10 image_shape: (28, 28, 1)
# Loading and compiling model
# Training model
# Epoch 1/120
# 354/353 [==============================] - 24s 67ms/step - loss: 0.4831 - categorical_accuracy: 0.9530 - precision: 0.9591 - recall: 0.9504 - auc: 0.9904 - val_loss: 0.1731 - val_categorical_accuracy: 0.9823 - val_precision: 0.9825 - val_recall: 0.9822 - val_auc: 0.9964
# Epoch 2/120
# 354/353 [==============================] - 24s 67ms/step - loss: 0.2277 - categorical_accuracy: 0.9766 - precision: 0.9769 - recall: 0.9763 - auc: 0.9926 - val_loss: 0.2738 - val_categorical_accuracy: 0.9713 - val_precision: 0.9715 - val_recall: 0.9710 - val_auc: 0.9929
# Epoch 3/120
# 354/353 [==============================] - 24s 67ms/step - loss: 0.1878 - categorical_accuracy: 0.9807 - precision: 0.9810 - recall: 0.9806 - auc: 0.9937 - val_loss: 0.2319 - val_categorical_accuracy: 0.9761 - val_precision: 0.9768 - val_recall: 0.9757 - val_auc: 0.9949
# Epoch 4/120
# ...
