# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.model_selection import validation_curve
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import seaborn as sns
from keras.datasets import mnist
from sklearn.preprocessing import scale
import import_ipynb
import sce_pipeline
# Out:
# importing Jupyter notebook from sce_pipeline.ipynb

# %%
(x_train_balanced, y_train_balanced), (x_test, y_test) = mnist.load_data()

# %%
x_train_imbalanced = np.load('../datasets/x_train_imbalanced.npy')
y_train_imbalanced_asym = np.load('../datasets/y_train_imbalanced_asym.npy')

# %%
x_train_imbalanced, y_train_imbalanced_asym, x_test, y_test = sce_pipeline.preprocess_sce(x_train_imbalanced, y_train_imbalanced_asym, x_test, y_test)

# %%
sce_pipeline.sce_train(x_train_imbalanced, y_train_imbalanced_asym, x_test, y_test, batch_size=128, epochs=50, alpha = 0.01, beta = 1.0)
# Out:
# Loading Data
# n_images 36344 num_classes 10 image_shape: (28, 28, 1)
# Loading and compiling model
# C:\Users\rahul\anaconda3\lib\site-packages\keras\optimizer_v2\gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# Training model
# Epoch 1/50
# 283/283 [==============================] - 18s 59ms/step - loss: 2.3747 - categorical_accuracy: 0.7496 - precision: 0.7575 - recall: 0.7466 - auc: 0.8832 - val_loss: 0.7394 - val_categorical_accuracy: 0.9264 - val_precision: 0.9291 - val_recall: 0.9254 - val_auc: 0.9824
# Epoch 2/50
# 283/283 [==============================] - 17s 60ms/step - loss: 2.1251 - categorical_accuracy: 0.7739 - precision: 0.7745 - recall: 0.7736 - auc: 0.8828 - val_loss: 0.2234 - val_categorical_accuracy: 0.9780 - val_precision: 0.9785 - val_recall: 0.9775 - val_auc: 0.9958
# Epoch 3/50
# ...
